# %% [markdown]
# # kc_house_dataset

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("kc_house_data.csv")
print(data.shape)
# Out:
# -------------------------------------------------------------------
# FileNotFoundError                 Traceback (most recent call last)
# <ipython-input-2-a4e5f35aca0e> in <module>
# ----> 1 data=pd.read_csv("kc_house_data.csv")
#       2 print(data.shape)
#
# /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File kc_house_data.csv does not exist: 'kc_house_data.csv'

# %%
data.describe()
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-3-2bb0b18689d4> in <module>
# ----> 1 data.describe()
#
# NameError: name 'data' is not defined

# %%
x=data["sqft_living"].values
y=data["price"].values

# %%
# %matplotlib inline
plt.scatter(x,y,40,c='r',label='original_data',marker='x')
plt.xlabel("sqft_living")
plt.ylabel("price")
plt.title("predict_price")
plt.grid(True,color='k')
plt.show()

# %%
mean_x=np.mean(x)
mean_y=np.mean(y)
n=len(x)
mean_x,mean_y
# Out:
# (2079.8997362698374, 540088.1417665294)

# %%
num=0
den=0
for i in range(n):
    num=num+((x[i]-mean_x)*y[i]-mean_y)
    den=den+((x[i]-mean_x)**2)
m=num/den
c=mean_y-(m*mean_x)
print(m,c)
# Out:
# 279.98326965696396 -42248.98695295665

# %%
y_pred=np.array([])
for i in range(n):
    p=(m*x[i])+c
    y_pred=np.append(y_pred,np.array([p]),axis=0)
print(y_pred)
# Out:
# [288131.27124226 677308.01606544 173338.13068291 ... 243333.94809715
#  405724.24449819 243333.94809715]

# %%
plt.plot(x,y_pred,c='m',label="regression_line")
plt.scatter(x,y,40,c='g',label='actual_data',marker='x')
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
nu=0
de=0
for i in range(n):
    nu=nu+((y_pred[i]-mean_y)**2)
    de=de+((y[i]-mean_y)**2)
r2=nu/de
r2
# Out:
# 0.49060669934227313
