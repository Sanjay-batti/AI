# %% [markdown]
# # profitdataset

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data.describe()
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-3-2bb0b18689d4> in <module>
# ----> 1 data.describe()
#
# NameError: name 'data' is not defined

# %%
x=data["population"].values
y=data["profit"].values

# %%
# %matplotlib inline
plt.scatter(x,y,40,c='r',label='original_data',marker='x')
plt.xlabel("population")
plt.ylabel("profit")
plt.title("predict_price")
plt.grid(True,color='k')
plt.show()

# %%
mean_x=np.mean(x)
mean_y=np.mean(y)
n=len(x)
mean_x,mean_y
# Out:
# (8.159799999999999, 5.839135051546393)

# %%
num=0
den=0
for i in range(n):
    num=num+((x[i]-mean_x)*y[i]-mean_y)
    den=den+((x[i]-mean_x)**2)
m=num/den
c=mean_y-(m*mean_x)
print(m,c)
# Out:
# 0.7990726426999772 -0.681137898356881

# %%
y_pred=np.array([])
for i in range(n):
    p=(m*x[i])+c
    y_pred=np.append(y_pred,np.array([p]),axis=0)
print(y_pred)
# Out:
# [ 4.20127586  3.73589595  6.12584232  4.91492763  4.00126797  6.01740816
#   5.29304881  6.17338714  4.50180708  3.35785468  3.88212624 10.63692701
#   3.90074463  6.03778451  3.82619116  3.61739348  4.4052791   3.41818467
#   4.45657957  4.96894494  4.26440259 15.51606457  3.70585082  4.37387555
#   3.76562145 14.45729332  9.56936596  8.07430105  9.84744324 17.06067199
#   3.51591125  4.58427137  6.70884572  4.0268383   5.88012748  5.65822501
#   5.78807431  3.79870306  9.57575854  4.39569023  3.63936797  4.81847957
#   8.6744046   3.93246782  5.57136581  4.98676426  3.37032021  3.95460213
#   8.66801202  3.74700306  5.34402964  3.56009997  5.25109749  5.39429131
#   4.37922933  4.40008513  4.33240368  3.82539208  6.75838822  6.87297524
#   6.3709978   3.45749904 16.32232887 11.23143706 14.46848033  5.08672825
#   5.94724958  7.49816967  3.71328219 15.57279873  7.41826241  5.1796604
#   4.11825221  5.09288111  3.33572037  4.55110986  5.34275113  3.34339147
#   7.52853443  3.40028544  3.89690909  3.4647706   4.3975281   7.12476303
#   4.52553953  6.12472361  6.65450878  4.1148961   3.73006272  3.36169023
#   3.87972902  5.42106024  4.00997787  3.5582621   5.94589116 10.02164108
#   3.66334015]

# %%
plt.plot(x,y_pred,c='m',label="regression_line")
plt.scatter(x,y,40,c='g',label='actual_data',marker='x')
plt.xlabel('population')
plt.ylabel('profit')
plt.legend()
plt.show()

# %%
nu=0
de=0
for i in range(n):
    nu=nu+((y_pred[i]-mean_y)**2)
    de=de+((y[i]-mean_y)**2)
r2=nu/de
r2
# Out:
# 0.3149370641990929
